# %% [markdown]
# ## Creating Lookups

# %%
#Dictionaries / Lookups
import pickle

def save_obj(obj, name ):
    with open(name + '.pkl', 'wb+') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
    
#---- Step 1: job level lookup
level_dict={
    "associate":"Contributor",
    "advisor":"Consultunt",
    "director":"Manager",
    "manager":"Manager",
    "lead":"Manager",
    "consultant":"Consultant",
    "principal":"Consultant",
    "professor":"Professor",
    "analyst":"Analyst",
    "student":"Student",
    "engineer":"Associate",
    "officer":"Executive",
    "executive":"Executive",
    "chief":"Executive",
    "president":"Executive",
    "partner":"Executive"}
#job functions lookup
func_dict={
    "recruit":"HR",
    "talent":"HR",
    "engineer":"Engineering",
    "software":"IT",
    "architect":"IT",
    "test":"IT",
    "associate":"Consultant Services",
    "service":"Services",
    "strat":"Strategy",
    "scien":"Research and Technology",
    "research":"Research",
    "marketing":"Marketing",
    "market":"Marketing",
    "analytics":"Analytics",
    "business":"Business",
    "operation":"Operations",
    "operat":"Operations",
    "retail":"Sales",
    "sale":"Sales",
    "financ":"Finances",
    "product":"Products",
    "advert":"Advertising",
    "entrepreneur":"Entrepreneur",
    "consult":"Consultant Services",
    "customer":"Customer Services",
    "training":"Education",
    "lecturer":"Education",
    "professor":"Education",
    "student":"Education",
    "partner":"Management",
    "manag":"Management",
    "executive":"Management",
    "chief":"Management",
    "president":"Management",
    "found":"Management"}

transforms = {"Sr.":"Senior",
              "Sr":"Senior",
              "Jr.": "Junior",
              "Jr": "Junior",
              "CEO":"Chief Executive Officer",
              "COO":"Chief Operating Officer",
              "CTO":"Chief Technology Officer",
              "CFO":"Chief Finance Officer",
              "GM":"General Manager",
              "VP":"Vice President",
              "SVP":"Senior Vice President",
              "EVP":"Executive Vice President",
              "/":"or",
              "&":'and'}
save_obj(level_dict,'Job_Levels')
save_obj(func_dict,'Job_Functions')
save_obj(transforms,'abbv_transforms')
